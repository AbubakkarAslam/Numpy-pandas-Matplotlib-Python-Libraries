# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
#1 Dataframe: The frame created by data, also the structure data create from column and row, also a table
df = pd.DataFrame([12,32,43],columns=['Column 1'])
print(df)
# Out:
#    Column 1
# 0        12
# 1        32
# 2        43

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [raw]
# df = pd.DataFrame(data)

# %%
df
# Out:
#    Column 1
# 0        12
# 1        32
# 2        43

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
Data = {
    "Name ": ["Ali","Saad", "Abu bakar","Abdulah"],
    "Age" : [12,32,23,8],
    "Salary":[1200,4321,4532,22113]
}

# %%
import pandas as pd
data = pd.DataFrame(Data)
print(data)
# Out:
#        Name   Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532
# 3    Abdulah    8   22113

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#2 Basic data frame understanding

# %%
data.head() # By default give top 5 row
# Out:
#        Name   Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532
# 3    Abdulah    8   22113

# %%
data.tail() # By default give last 5 row
# Out:
#        Name   Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532
# 3    Abdulah    8   22113

# %%
data.shape # Tell the total rows and columns
# Out:
# (4, 3)

# %%
data.columns # It tell the all column names from the Dataframe
# Out:
# Index(['Name ', 'Age', 'Salary'], dtype='object')

# %%
#Change column name
data.rename(columns = {"Salary" : "Montholy_Salary"})
# Out:
#        Name   Age  Montholy_Salary
# 0        Ali   12             1200
# 1       Saad   32             4321
# 2  Abu bakar   23             4532
# 3    Abdulah    8            22113

# %%
data
# Out:
#        Name   Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532
# 3    Abdulah    8   22113

# %%
# To change the column name permanenty we have to use to methods 
# Firts methods: First method is to store the complete data frame in different variable like this
data1 = data.rename(columns={"Salary":"Monthaly_Salary"})
data1
# Out:
#        Name   Age  Monthaly_Salary
# 0        Ali   12             1200
# 1       Saad   32             4321
# 2  Abu bakar   23             4532
# 3    Abdulah    8            22113

# %%
#Secound method: Second method is to use the paramenter in the same variable with inplace  = True by default it is false but we will make is True
data.rename(columns = {"Salary" : "Monthaly_Salary"},inplace = True)
data
# Out:
#        Name   Age  Monthaly_Salary
# 0        Ali   12             1200
# 1       Saad   32             4321
# 2  Abu bakar   23             4532
# 3    Abdulah    8            22113

# %%
data.info() # it tell the information of the whole dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             4 non-null      object
#  1   Age              4 non-null      int64
#  2   Monthaly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
data.describe() # it describe the dataframe but it tells the statistical summary of all the numerical columns
# Out:
#              Age  Monthaly_Salary
# count   4.000000         4.000000
# mean   18.750000      8041.500000
# std    10.874282      9503.892974
# min     8.000000      1200.000000
# 25%    11.000000      3540.750000
# 50%    17.500000      4426.500000
# 75%    25.250000      8927.250000
# max    32.000000     22113.000000

# %%
#3 Save and load data from csv

# %%
 # to save or export the dataframe into the system
data.to_csv("Test_data.csv")

# %%
# to remove the indexies from dataframe By default it is True but we will do it False
data.to_csv("Test_data.csv",index = False)

# %%
# To load or import the dataframe from the system 
load_data_frame = pd.read_csv("Test_data.csv")

# %%
load_data_frame
# Out:
#        Name   Age  Monthaly_Salary
# 0        Ali   12             1200
# 1       Saad   32             4321
# 2  Abu bakar   23             4532
# 3    Abdulah    8            22113
# 4      Ubaid   26           453112

# %%
#4. Rows and Columns Selections and perform operations

# %%
#Select column
data[['Name', 'Age']]
# Out:
#         Name  Age
# 0        Ali   12
# 1       Saad   32
# 2  Abu bakar   23
# 3    Abdulah    8

# %%
#Select Rows
# There are two methods to select rows

# %%
# First method: the first method works on a label base
#loc - index label based
data.loc[data.Name=="Abu bakar"]
#condition based
data.loc[(data.Name=="Abu bakar") & (data.Salary<=50000)]
# Out:
#         Name  Age  Salary
# 2  Abu bakar   23    4532

# %%
data.loc[0:2]
# the last value does not include in 'iloc' but include in 'loc' function
# Out:
#         Name  Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532

# %%
# secound method: The secound method works on index value base
# data.iloc[0]
#multiple index value needed
data.iloc[0:3] # [start:stop:step]
# the last value does not include in 'iloc' but include in 'loc' function
# Out:
#         Name  Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532

# %%
#05 Filter Dataframe

# %%
data
# Out:
#        Name   Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532
# 3    Abdulah    8   22113

# %%
data['Age']>18 # it tells how many value are True and False.
#if we need all the true values then we will use the bellow method
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: Age, dtype: bool

# %%
data[data['Age']>=18]
# Out:
#         Name  Age  Salary
# 1       Saad   32    4321
# 2  Abu bakar   23    4532

# %%
#if we want multiple conditionn value in one line 
data[(data['Age']<18) & (data['Salary']>=1200)]
# Out:
#       Name  Age  Salary
# 0      Ali   12    1200
# 3  Abdulah    8   22113

# %%
# I want all the rows and columns of matched conditions and unmatched conditions give the null but doest not change the rows and columns

# %%
data.where(data['Age']>=18)
# Out:
#        Name    Age  Salary
# 0        NaN   NaN     NaN
# 1       Saad  32.0  4321.0
# 2  Abu bakar  23.0  4532.0
# 3        NaN   NaN     NaN

# %%
# NaN does not show i want somethings should show rater than NaN
# we will use the other parameter
data.where(data['Age']>=18,other = 'Not matched')
# Out:
#           Name          Age       Salary
# 0  Not matched  Not matched  Not matched
# 1         Saad           32         4321
# 2    Abu bakar           23         4532
# 3  Not matched  Not matched  Not matched

# %%
#06 Row and columns - Operations(Add,Update,Delete)

# %%
data
# Out:
#         Name  Age  Salary
# 0        Ali   12    1200
# 1       Saad   32    4321
# 2  Abu bakar   23    4532
# 3    Abdulah    8   22113

# %%
#Add new column and write data
data['Positions'] = ['Employee','HR','CEO','Manager']

# %%
data
# Out:
#         Name  Age  Salary Positions
# 0        Ali   12    1200  Employee
# 1       Saad   32    4321        HR
# 2  Abu bakar   23    4532       CEO
# 3    Abdulah    8   22113   Manager

# %%
# If we want and other column but with multiple of other like bonus the we will create like this
data['Bonus'] = data['Salary'] * 0.2
data
# Out:
#         Name  Age  Salary Positions   Bonus
# 0        Ali   12    1200  Employee   240.0
# 1       Saad   32    4321        HR   864.2
# 2  Abu bakar   23    4532       CEO   906.4
# 3    Abdulah    8   22113   Manager  4422.6

# %%
# if to add the rows data then we will use the 'loc' method
data.loc[len(data)]= ["Ahmed",20,5000,'IT',1000]
data
# Out:
#         Name  Age  Salary Positions   Bonus
# 0        Ali   12    1200  Employee   240.0
# 1       Saad   32    4321        HR   864.2
# 2  Abu bakar   23    4532       CEO   906.4
# 3    Abdulah    8   22113   Manager  4422.6
# 4      Ahmed   20    5000        IT  1000.0

# %%
len(data)
# Out:
# 5

# %%
# update the value there are two methods

# %%
# Method 1 : update the value by using the index name like 0,1,2,3,4,5,6....
data.loc[0,'Salary'] = 1232113

# %%
data
# Out:
#         Name  Age   Salary Positions   Bonus
# 0        Ali   12  1232113  Employee   240.0
# 1       Saad   32     4321        HR   864.2
# 2  Abu bakar   23     4532       CEO   906.4
# 3    Abdulah    8    22113   Manager  4422.6
# 4      Ahmed   20     5000        IT  1000.0

# %%
# Method 1 : update the value by using the column name like Name == 'Abu bakar'
data.loc[data.Name=='Abu bakar','Salary'] = 120000
data
# Out:
#         Name  Age   Salary Positions   Bonus
# 0        Ali   12  1232113  Employee   240.0
# 1       Saad   32     4321        HR   864.2
# 2  Abu bakar   23   120000       CEO   906.4
# 3    Abdulah    8    22113   Manager  4422.6
# 4      Ahmed   20     5000        IT  1000.0

# %%
#Delete value - row and column

# %%
data.drop(data[data.Name=='Ahmed'].index,inplace=True) #delete row , axis = 0
data
# Out:
#         Name  Age   Salary Positions   Bonus
# 0        Ali   12  1232113  Employee   240.0
# 1       Saad   32     4321        HR   864.2
# 2  Abu bakar   23   120000       CEO   906.4
# 3    Abdulah    8    22113   Manager  4422.6

# %%
#Secound method to delete row with index lable
data.drop(1.,axis=0,inplace=True) #delete row , axis = 0
data

# %%
data.drop('Bonus',axis=1,inplace=True) #delete columns , axis=1
data
# Out:
#         Name  Age   Salary Positions
# 0        Ali   12  1232113  Employee
# 1       Saad   32     4321        HR
# 2  Abu bakar   23   120000       CEO
# 3    Abdulah    8    22113   Manager

# %%
#for multiple delete columns

# %%
# data.drop(['Name','Age','Salary'],axis=1)

# %%
# Sort value -  in ascending and descending 
data.sort_values('Salary') #in ascending
# Out:
#         Name  Age   Salary Positions
# 1       Saad   32     4321        HR
# 3    Abdulah    8    22113   Manager
# 2  Abu bakar   23   120000       CEO
# 0        Ali   12  1232113  Employee

# %%
data.sort_values('Salary',ascending= False) #in dscending
# Out:
#         Name  Age   Salary Positions
# 0        Ali   12  1232113  Employee
# 2  Abu bakar   23   120000       CEO
# 3    Abdulah    8    22113   Manager
# 1       Saad   32     4321        HR

# %%
#07 Working with date time value or datatype

# %%
data['Date of Joinnig'] = ['2026-1-21','2026-1-22','2026-2-3','2026-3-1']

# %%
data
# Out:
#        Name   Age  Salary Date of Joinnig
# 0        Ali   12    1200       2026-1-21
# 1       Saad   32    4321       2026-1-22
# 2  Abu bakar   23    4532        2026-2-3
# 3    Abdulah    8   22113        2026-3-1

# %%
data['Date of Joinnig'].dtype
# Out:
# dtype('O')

# %%
data.rename(columns={'Date of Joinnig':'DOJ'},inplace=True)
data
# Out:
#        Name   Age  Salary        DOJ
# 0        Ali   12    1200  2026-1-21
# 1       Saad   32    4321  2026-1-22
# 2  Abu bakar   23    4532   2026-2-3
# 3    Abdulah    8   22113   2026-3-1

# %%
data['DOJ'] = pd.to_datetime(data['DOJ'])# Convert date Object into date and time

# %%
data['DOJ'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#formate the date
data['DOJ'] = pd.to_datetime(data['DOJ'],format='%d-%m-%Y')

# %%
data
# Out:
#        Name   Age  Salary        DOJ
# 0        Ali   12    1200 2026-01-21
# 1       Saad   32    4321 2026-01-22
# 2  Abu bakar   23    4532 2026-02-03
# 3    Abdulah    8   22113 2026-03-01

# %%
data['DOJ'].dt.year # to find the year from DOJ
data['DOJ'].dt.month # to find the month from DOJ
data['DOJ'].dt.month_name() # to find the month name from DOJ
data['DOJ'].dt.day # to find the day from DOJ
data['DOJ'].dt.day_name() # to find the day name from DOJ
# Out:
# 0    Wednesday
# 1     Thursday
# 2      Tuesday
# 3       Sunday
# Name: DOJ, dtype: object

# %%
data['Month'] = data['DOJ'].dt.month_name() # joing months

# %%
data
# Out:
#        Name   Age  Salary        DOJ     Month
# 0        Ali   12    1200 2026-01-21   January
# 1       Saad   32    4321 2026-01-22   January
# 2  Abu bakar   23    4532 2026-02-03  February
# 3    Abdulah    8   22113 2026-03-01     March

# %%
data['Probation time end data ']= data['DOJ'] + pd.Timedelta(days=90) #use to add the extra days in DOJ

# %%
data
# Out:
#        Name   Age  Salary        DOJ     Month Probation time end data
# 0        Ali   12    1200 2026-01-21   January               2026-04-21
# 1       Saad   32    4321 2026-01-22   January               2026-04-22
# 2  Abu bakar   23    4532 2026-02-03  February               2026-05-04
# 3    Abdulah    8   22113 2026-03-01     March               2026-05-30

# %%
#08 Handling missing values

# %%
import numpy as np

# %%
data.rename(columns= {'Name ':'Name'},inplace = True)

# %%
data.loc[data.Name=='Ali','Salary'] = np.nan # for make the value null in any row

# %%
data
# Out:
#         Name  Age   Salary        DOJ     Month Probation time end data
# 0        Ali   12      NaN 2026-01-21   January               2026-04-21
# 1       Saad   32   4321.0 2026-01-22   January               2026-04-22
# 2  Abu bakar   23   4532.0 2026-02-03  February               2026-05-04
# 3    Abdulah    8  22113.0 2026-03-01     March               2026-05-30

# %%
data.isnull() # it tells the null value 'True' at any where in Dataframe
# Out:
#     Name    Age  Salary    DOJ  Month  Probation time end data
# 0  False  False    True  False  False                     False
# 1  False  False   False  False  False                     False
# 2  False  False   False  False  False                     False
# 3  False  False   False  False  False                     False

# %%
data.isnull().sum() # it gives the totl nul vaues
# Out:
# Name                        0
# Age                         0
# Salary                      1
# DOJ                         0
# Month                       0
# Probation time end data     0
# dtype: int64

# %%
data.fillna(321121) # it add the value in null sector
# Out:
#         Name  Age    Salary        DOJ     Month Probation time end data
# 0        Ali   12  321121.0 2026-01-21   January               2026-04-21
# 1       Saad   32    4321.0 2026-01-22   January               2026-04-22
# 2  Abu bakar   23    4532.0 2026-02-03  February               2026-05-04
# 3    Abdulah    8   22113.0 2026-03-01     March               2026-05-30

# %%
data
# Out:
#         Name  Age   Salary        DOJ     Month Probation time end data
# 0        Ali   12      NaN 2026-01-21   January               2026-04-21
# 1       Saad   32   4321.0 2026-01-22   January               2026-04-22
# 2  Abu bakar   23   4532.0 2026-02-03  February               2026-05-04
# 3    Abdulah    8  22113.0 2026-03-01     March               2026-05-30

# %%
#09 Aggregasion and group By

# %%
# To find total value of any thing in dataframe
data['Name'].value_counts()
# Out:
# Name
# Ali          1
# Saad         1
# Abu bakar    1
# Abdulah      1
# Name: count, dtype: int64

# %%
# To find total value of any specific data in dataframe
data[data['Month']=='January'].value_counts()
# Out:
# Name  Age  Salary  DOJ         Month    Probation time end data
# Saad  32   4321.0  2026-01-22  January  2026-04-22                  1
# Name: count, dtype: int64

# %%
#group by it tell total sum of any integer column in data frame

# %%
data.groupby('Month')['Salary'].sum() # Agrregation based on group by
# Out:
# Month
# February     4532.0
# January      4321.0
# March       22113.0
# Name: Salary, dtype: float64

# %%
data.groupby('Month').agg({'Salary':'mean','Name':'count'})
# Out:
#            Salary  Name
# Month
# February   4532.0     1
# January    4321.0     2
# March     22113.0     1
